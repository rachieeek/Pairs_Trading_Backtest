# %%
import pandas as pd

# %%
df = pd.read_csv('data/Information Technology/AAPL.csv')
df
# Out:
#            Date       Close        High         Low        Open     Volume  \
# 0    2024-02-27  181.771698  183.055629  178.716119  180.248890   54318900
# 1    2024-02-28  180.567398  182.259406  179.283467  181.652272   48953900
# 2    2024-02-29  179.900543  181.711997  178.686276  180.418104  136682600
# 3    2024-03-01  178.815674  179.681580  176.546390  178.706190   73488000
# 4    2024-03-04  174.277115  176.068644  172.973259  175.322168   81510100
# ..          ...         ...         ...         ...         ...        ...
# 246  2025-02-20  245.830002  246.779999  244.289993  244.940002   32316900
# 247  2025-02-21  245.550003  248.690002  245.220001  245.949997   53197400
# 248  2025-02-24  247.100006  248.860001  244.419998  244.929993   51326400
# 249  2025-02-25  247.039993  250.000000  244.910004  248.000000   47957800
# 250  2025-02-26  243.270004  244.979996  241.419998  244.330002   18673890
#
#     Ticker                Industry
# ...

# %%
df = df.rename(columns={df.columns[0]: 'Date'})

# %%
df
# Out:
#            Date               Close                High                 Low  \
# 0        Ticker                GOOG                GOOG                GOOG
# 1          Date                 NaN                 NaN                 NaN
# 2    2024-02-27  139.59841918945312  139.98702230085874  138.00414143775035
# 3    2024-02-28  136.93795776367188   138.7813403669397  136.15079285778955
# 4    2024-02-29    139.279541015625  139.44893053594961  137.07746204724742
# ..          ...                 ...                 ...                 ...
# 248  2025-02-20  186.63999938964844   187.1199951171875  184.60000610351562
# 249  2025-02-21   181.5800018310547  187.47000122070312   181.1300048828125
# 250  2025-02-24  181.19000244140625  185.08999633789062   180.8800048828125
# 251  2025-02-25   177.3699951171875  180.75999450683594  176.77000427246094
# 252  2025-02-26   176.8699951171875   178.0800018310547  174.92999267578125
#
# ...

# %%
# rename first column to 'Date'
df_temp = df.rename(columns={df.columns[0]: 'Date'}).iloc[2:].reset_index(drop=True)
df_temp
# Out:
#     Date               Close                High                 Low  \
# 0      1   137.5856475830078   139.4987717713732  137.48102776134397
# 1      2   133.7195281982422   136.1408361111928  132.38432937436133
# 2      3    133.301025390625  133.54017159058074  131.07901373110874
# 3      4  132.08538818359375  134.25759095655891    131.477571580588
# 4      5   134.7558135986328   135.3337388830001  132.18504879747854
# ..   ...                 ...                 ...                 ...
# 243  244  186.63999938964844   187.1199951171875  184.60000610351562
# 244  245   181.5800018310547  187.47000122070312   181.1300048828125
# 245  246  181.19000244140625  185.08999633789062   180.8800048828125
# 246  247   177.3699951171875  180.75999450683594  176.77000427246094
# 247  248  177.14999389648438   178.0800018310547  174.92999267578125
#
#                    Open    Volume Ticker                Industry
# 0     139.1101686581765  28522000   GOOG  Communication Services
# ...

# %%
### Plot CSCO vs MCHP

df_csco = pd.read_csv('data/Information Technology/CSCO.csv')
df_mchp = pd.read_csv('data/Information Technology/KEYS.csv')

# plot
import matplotlib.pyplot as plt
plt.plot(df_csco['Close'], label='CSCO')
plt.plot(df_mchp['Close'], label='KEYS')
plt.legend()
plt.show()
